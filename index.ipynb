# %% [markdown]
# # Subplots and Enumeration - Lab
#
# ## Introduction
#
# In this lab, we'll get some practice creating **_subplots_**, and explore how we can use the `enumerate` keyword to make creating them a bit easier!
#
# ## Objectives
#
# You will be able to:
#
# * Use python's `enumerate` keyword for lists where we also to access the index
# * Create basic subplots with matplotlib
# * Use `enumerate` to write effective, pythonic code when creating subplots
#
# ## Getting Started
#
# For this lab, we'll explore a dataset containing yearly population data about different countries and regions around the globe. Let's start by importing the dataset so we can get to work.
#
# In the cell below:
#
# * Import pandas and set the standard alias of `pd`
# * Import the `pyplot` module from `matplotlib` and set the standard alias of `plt`
# * Set matplotlib visualizations to appear inline with the command `%matplotlib inline`

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now, let's import the dataset.
#
# In the cell below:
#
# * Use pandas to read in the data stored in the file `population.csv`.
# * Print the head of the dataframe to ensure everything loaded correctly and get a feel for what this dataset contains.

# %%
df = pd.read_csv('population.csv')
df.head()
# Out:
#   Country Name Country Code  Year        Value
# 0   Arab World          ARB  1960   92490932.0
# 1   Arab World          ARB  1961   95044497.0
# 2   Arab World          ARB  1962   97682294.0
# 3   Arab World          ARB  1963  100411076.0
# 4   Arab World          ARB  1964  103239902.0

# %% [markdown]
# Our columns look fairly standard. Let's take a look at the `value_counts()` of the `'Country Name'` column to get a feel for how many years there are per country.
#
# Do this now in the cell below.

# %%
df.groupby('Country Name')['Year'].count()
# Out:
# Country Name
# Afghanistan                 57
# Albania                     57
# Algeria                     57
# American Samoa              57
# Andorra                     57
# Angola                      57
# Antigua and Barbuda         57
# Arab World                  57
# Argentina                   57
# Armenia                     57
# Aruba                       57
# Australia                   57
# Austria                     57
# Azerbaijan                  57
# Bahamas, The                57
# Bahrain                     57
# Bangladesh                  57
# Barbados                    57
# Belarus                     57
# Belgium                     57
# Belize                      57
# Benin                       57
# Bermuda                     57
# Bhutan                      57
# Bolivia                     57
# Bosnia and Herzegovina      57
# Botswana                    57
# Brazil                      57
# British Virgin Islands      57
# Brunei Darussalam           57
#                             ..
# Syrian Arab Republic        57
# Tajikistan                  57
# Tanzania                    57
# Thailand                    57
# Timor-Leste                 57
# Togo                        57
# Tonga                       57
# Trinidad and Tobago         57
# Tunisia                     57
# Turkey                      57
# Turkmenistan                57
# Turks and Caicos Islands    57
# Tuvalu                      57
# Uganda                      57
# Ukraine                     57
# United Arab Emirates        57
# United Kingdom              57
# United States               57
# Upper middle income         57
# Uruguay                     57
# Uzbekistan                  57
# Vanuatu                     57
# Venezuela, RB               57
# Vietnam                     57
# Virgin Islands (U.S.)       57
# West Bank and Gaza          27
# World                       57
# Yemen, Rep.                 57
# Zambia                      57
# Zimbabwe                    57
# Name: Year, Length: 263, dtype: int64

# %% [markdown]
# ## Groupings and Subplots
#
# When creating subplots, it makes sense that we'll usually want the plots to contain data that is related to one another, so that the subplots will make it easy to visually compare and see trends or patterns. The easiest way to do this is to group our data by the types of information we're most interested in seeing. For this dataset, that means that we can group by `'Country Name'`, by `'Country Code'`, or by `'Year'`. Let's start by grouping by name.
#
# For our first subplot, we'll create 1 row containing 2 subplots. Let's start by getting some data for each of our plots. We'll start by getting some data to plot.  We'll do this by slicing data for the USA and Canada and storing them in separate variables.
#
# In the cell below:
#
# * Slice all the rows for '`United States`' and store them in the appropriate variable.
# * Slice all the rows for '`Canada`' and store them in the appropriate variable.
# * Inspect the `.head()` of each to ensure that we grabbed the data correctly.

# %%
usa = df[df['Country Name']=='United States']


canada = df[df['Country Name']=='Canada']

# %%
display(usa.head())
display(canada.head())
# Out:
#         Country Name Country Code  Year        Value
# 14288  United States          USA  1960  180671000.0
# 14289  United States          USA  1961  183691000.0
# 14290  United States          USA  1962  186538000.0
# 14291  United States          USA  1963  189242000.0
# 14292  United States          USA  1964  191889000.0
#      Country Name Country Code  Year       Value
# 4617       Canada          CAN  1960  17909009.0
# 4618       Canada          CAN  1961  18271000.0
# 4619       Canada          CAN  1962  18614000.0
# 4620       Canada          CAN  1963  18964000.0
# 4621       Canada          CAN  1964  19325000.0

# %% [markdown]
# Now that we have our data ready to go, lets go ahead and create a basic subplot. For our first batch of subplots, we'll use the quick way by making use of `plt.subplot()` and passing in the number of rows, number of columns, and the number of the subplot that we want to create. Then, we'll create our plot by passing in the corresponding data.
#
# When we call `plt.subplot()`, it will return an `ax` (short for 'axis') object that corresponds to the 3rd parameter we pass in--the actual plot we will want to create. To create subplots on the fly with this method, we'll:
#
# 1. Get the `ax` object for the first plot  in the subplot we want to create. Store this in the variable `ax1`.
# 2. Call `.plot()` on the `usa` DataFrame, and specify the following parameters:
#     * `x='Year'`
#     * `y='Value'`
#     * `ax=ax1`
# 3. Use the `ax1` object's methods to do any labeling we find necessary.
# 4. Repeat the process for `canada` with the second plot. Store this axis in `ax2`.
#
# Do this now in the cell below.

# %%
ax1 = plt.subplot(211)
usa.plot.scatter(x = 'Year', y='Value', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Population')
ax1.set_title('US population by Year')
ax2 = plt.subplot(212)
canada.plot.scatter(x = 'Year', y='Value', ax=ax2, color = 'red')
ax2.set_xlabel('Year')
ax1.set_ylabel('Population')
ax1.set_title('Canada population by Year')
plt.show()

# %% [markdown]
# Our plots look pretty good, but they're a bit squished together, and the plots themselves are much too small, which squishes the axis values.  Both of these problems have an easy fix. We'll begin by using `plt.figure()` and passing in a larger `figsize` of `(20, 10)` to tell matplotlib we want the full subplot to be 20 inches by 10.
#
# We can fix the spacing quite easily by using `plt.subplots_adjust()` and changing the amount of space in between our plots. The [documentation for `subplots_adjust`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html) tells us that the parameter we need to adjust is `wspace`. This is set to `0.2` by default, meaning that the amount of space between our plots is equal to 20% of the width of the plots. Let's set `wspace=0.4`, and see how that looks.
#
# In the cell below:
#
# * Call `plt.figure()` and use the `figsize` parameter to set the size of the total subplot to 20 inches wide by 10 inches tall. Remember to pass these values in as a tuple, with width first and height second.
# * Copy the visualization code from the cell above into the cell below.
# * After setting the title for the Canada plot, add the line `plt.subplots_adjust()` and pass in the parameter `wspace=0.4`.

# %%
plt.figure(figsize=(20,10))
ax1 = plt.subplot(211)
usa.plot.scatter(x = 'Year', y='Value', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Population')
ax1.set_title('US population by Year')
ax2 = plt.subplot(212)
canada.plot.scatter(x = 'Year', y='Value', ax=ax2, color = 'red')
ax2.set_xlabel('Year')
ax1.set_ylabel('Population')
ax1.set_title('Canada population by Year')
plt.subplots_adjust(hspace=0.4)
plt.show()

# %% [markdown]
# Much better!
#
# Next, we'll see some advanced methods for creating subplots. But, before we do that, let's take a brief detour and learn about the `enumerate` keyword!
#
# ## Using `enumerate()`
#
# Python's `enumerate()` keyword is a special type of for loop. It works just like a regular for-loop, with 1 major difference--instead of just returning the next object with each iteration of the loop, it also returns the index of the object from the collection we're looping through!
#
# Run the example code in the cell below, and examine the output. That should make it clear what is happening.

# %%
sample_list = ['foo', 'bar', 'baz']

for index, value in enumerate(sample_list):
    print("Index: {}      Value: {}".format(index, value))
# Out:
# Index: 0      Value: foo
# Index: 1      Value: bar
# Index: 2      Value: baz

# %% [markdown]
# The `enumerate` keywor is extremely helpful anytime we need to do something that needs the index of the item we're looping through. Let's try an example.
#
# In the cell below:
# * `enumerate()` through `sample_list_2` in the cell below
# * For any item in `sample_list_2`, append it to the `odds` list if it's index is an odd number.
# * Once the loop has finished, print `odds`.

# %%
sample_list_2 = ['item at Index ' + str(i) for i in range(10)]
odds = []

# Write your code below this line
for i, v in enumerate(sample_list_2):
    if i%2:
        odds.append(v)


# Write your code above this line

odds
# Expected Output: 
# ['item at Index 1',
#  'item at Index 3',
#  'item at Index 5',
#  'item at Index 7',
#  'item at Index 9']
# Out:
# ['item at Index 1',
#  'item at Index 3',
#  'item at Index 5',
#  'item at Index 7',
#  'item at Index 9']

# %% [markdown]
# Great! There are plenty of situations where `enumerate()` comes in very handy. By allowing us to get the index and the value at the same time, it makes it simple to do something to something with one based on the value of the other. This is a natural requirement of subplots.
#
# ## Enumerating with Subplots
#
# To end this lab, we'll see how we can use `enumerate` to easily subplot this entire dataframe by country--all 263 of them!
#
# It will work like this. We'll begin by grouping each row in our DataFrame by `'Country Name'`. Then, we'll create a `plt.figure()` and set the figure size to `(20,40)`. We'll also set the `facecolor` to `'white'`, so that it's a bit easier to read.
#
# Then comes the fun part. We'll enumerate through our grouped DataFrame. Just looping through a grouped DataFrame returns a tuple containing the index and the rows with that country name. Since we're grouped by `"Country Name"`, this means that the index will actually be the `'Country Name'`. However, we're not just looping through the grouped DataFrame--we're `enumerate`-ing through it!
#
# ```python
# for index, (value1, value2) in enumerate(grouped_DataFrame):
#     # index is an integer, starting at 0 and counting up by 1 just
#     # like we would expect a for loop to do
#
#     #(value1, value2) is a tuple containing the name of the country as value 1
#     # (since it is acting as the index because we grouped everything by it),
#     # and value 2 is all the rows that belong to that country's group.
#
# ```
#
# This means that the `index` for our enumeration will be an integer value that counts higher by 1 with each country. If we just add 1 to it (because subplots start counting at 1, but python starts counting at 0), then this number will correspond with the index we need to pass in as the third parameter in `plt.subplot()`--the parameter that specifies which plot inside the subplot should show the plot we're about to create.
#
# Don't worry if this seems confusing--the code below has been commented to help you.

# %%
grouped_df = df.groupby('Country Name')

# %%
for index, (country,value) in enumerate(grouped_df,1):
    print(index, value.columns)
# Out:
# 1 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 2 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 3 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 4 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 5 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 6 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 7 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 8 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 9 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 10 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 11 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 12 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 13 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 14 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 15 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 16 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 17 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 18 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 19 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 20 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 21 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 22 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 23 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 24 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 25 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 26 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 27 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 28 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 29 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 30 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 31 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 32 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 33 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 34 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 35 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 36 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 37 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 38 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 39 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 40 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 41 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 42 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 43 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 44 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 45 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 46 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 47 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 48 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 49 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 50 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 51 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 52 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 53 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 54 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 55 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 56 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 57 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 58 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 59 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 60 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 61 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 62 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 63 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 64 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 65 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 66 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 67 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 68 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 69 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 70 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 71 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 72 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 73 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 74 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 75 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 76 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 77 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 78 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 79 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 80 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 81 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 82 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 83 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 84 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 85 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 86 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 87 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 88 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 89 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 90 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 91 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 92 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 93 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 94 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 95 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 96 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 97 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 98 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 99 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 100 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 101 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 102 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 103 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 104 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 105 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 106 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 107 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 108 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 109 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 110 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 111 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 112 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 113 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 114 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 115 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 116 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 117 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 118 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 119 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 120 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 121 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 122 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 123 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 124 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 125 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 126 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 127 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 128 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 129 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 130 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 131 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 132 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 133 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 134 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 135 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 136 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 137 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 138 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 139 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 140 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 141 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 142 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 143 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 144 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 145 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 146 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 147 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 148 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 149 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 150 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 151 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 152 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 153 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 154 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 155 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 156 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 157 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 158 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 159 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 160 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 161 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 162 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 163 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 164 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 165 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 166 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 167 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 168 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 169 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 170 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 171 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 172 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 173 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 174 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 175 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 176 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 177 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 178 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 179 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 180 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 181 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 182 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 183 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 184 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 185 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 186 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 187 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 188 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 189 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 190 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 191 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 192 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 193 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 194 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 195 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 196 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 197 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 198 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 199 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 200 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 201 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 202 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 203 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 204 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 205 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 206 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 207 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 208 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 209 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 210 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 211 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 212 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 213 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 214 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 215 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 216 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 217 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 218 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 219 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 220 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 221 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 222 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 223 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 224 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 225 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 226 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 227 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 228 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 229 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 230 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 231 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 232 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 233 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 234 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 235 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 236 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 237 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 238 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 239 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 240 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 241 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 242 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 243 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 244 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 245 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 246 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 247 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 248 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 249 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 250 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 251 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 252 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 253 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 254 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 255 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 256 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 257 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 258 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 259 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 260 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 261 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 262 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')
# 263 Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')

# %%
# Group the DataFrame by Country Name--this line has been provided for you
grouped_df = df.groupby('Country Name')

# pass in figsize=(20,40), and also set the facecolor parameter to 'white'
plt.figure(figsize=(20,40), facecolor='red')

# Complete the line below so that the first loop variable is the called index,
# and the second loop variable is the tuple (countryname, population). 
for index, (countryname, population) in enumerate(grouped_df,1):
    
    # Get the unique subplot where the plot we're creating during this iteration
    # of the loop will live. Our subplot will be 30 rows of 9 plots each. 
    # Set the third value to be index+1
    ax = plt.subplot(30, 9, index)
    
    # Complete the line to create the plot for this subplot. 
    # Same visualizations as we created above!
    population.plot(x='Year', y='Value', ax=ax, legend=False)
    
    # Set the title of each plot, so we know which country it represents
    ax.set_title(countryname)

# %% [markdown]
# Great job! Being able to effectively create subplots with matplotlib is a solid data visualization skill to have--and using `enumerate()` makes our code that much simpler!
#
# ## Summary
#
# In this lab, we learned how to create advanced subplots using `enumerate()` on grouped DataFrames!
